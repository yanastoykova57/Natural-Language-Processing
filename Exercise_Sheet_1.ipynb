# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 1

# %%
#imports for all exercises
import nltk
#nltk.download()
from nltk.book import *

# %% [markdown]
# ### Exercise 1
#
# How many words are there in `text2` from `nltk.book`? How many distinct words are there? Calculate the lexical diversity.

# %%
word_count = len(text2)
print("Number of words in text2: ", word_count)

distinct_words = len(set(text2))
print("Number of distinct words in text2: ", distinct_words)

lexical_diversity = distinct_words/word_count
print("Lexical diversity: ", lexical_diversity)
# Out:
# Number of words in text2:  141576
# Number of distinct words in text2:  6833
# Lexical diversity:  0.04826383002768831

# %% [markdown]
# ### Exercise 2
#
# Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
import matplotlib.pylab as plt
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# At first glance, I notice that the 2 female characters are mentioned more frequently than the male ones, which would make them the main characters of the story.
#
# Willoughby and Marianne seem to be a couple, since Willoughby is mentioned only when Marianne is. The same goes for Elinor and Edward, even though the correlation isn't as strong.

# %% [markdown]
# ### Exercise 3
#
# Find the collocations in `text6`.

# %%
text6.collocations()
# Out:
# BLACK KNIGHT; clop clop; HEAD KNIGHT; mumble mumble; Holy Grail;
# squeak squeak; FRENCH GUARD; saw saw; Sir Robin; Run away; CARTOON
# CHARACTER; King Arthur; Iesu domine; Pie Iesu; DEAD PERSON; Round
# Table; clap clap; OLD MAN; dramatic chord; dona eis

# %% [markdown]
# ### Exercise 4
#
# Use only the `index()` function to find all the indexes of the word "sunset" in `text9`.

# %%
indexes=[]

for i, word in enumerate(text9):
    if word == "sunset":
        indexes.append(i)
    
print(indexes)
# Out:
# [629, 642, 1432, 1650, 13335, 13381, 16313, 27014, 49340, 52092, 60857, 60862, 64721, 64736]

# %% [markdown]
# ### Exercise 5
#
# What is the difference between the following two lines? Calculate the two values:
#
#     len(sorted(set(w.lower() for w in text1)))
#     len(sorted(w.lower() for w in set(text1)))

# %% [markdown]
# In the first line we go through each word in text1 and set all the letters in it to lowercase. Then all duplicates are removed and subsequently sorted. Lastly, the number of these unique lowercase words in text1 is calculated.
#
# In the second line first the duplicates are removed from text1. Then, the remaining words are set to lowercase and subsequently sorted. Lastly, we get the number of lowercase unique words in text1.
#
# The difference in the number of words is because in the second line, words like "a" and "A" would be counted as separate words.

# %%
len(sorted(set(w.lower() for w in text1)))
# Out:
# 17231

# %%
len(sorted(w.lower() for w in set(text1)))
# Out:
# 19317

# %% [markdown]
# ### Exercise 6
#
# Write the slice expression that extracts the last two words of `text2`.

# %%
text2[-2:]
# Out:
# ['THE', 'END']

# %% [markdown]
# ### Exercise 7
#
# Find all the four-letter words in `text6`. With the help of a frequency distribution (`FreqDist`), show these words in decreasing order of frequency.

# %%
words = [w for w in text6 if len(w) == 4]
fdist = FreqDist(words)
fdist.most_common()
# Out:
# [('that', 84),
#  ('your', 75),
#  ('What', 65),
#  ('this', 59),
#  ('Well', 54),
#  ('HEAD', 54),
#  ('have', 53),
#  ('boom', 45),
#  ('clop', 39),
#  ('with', 38),
#  ('away', 38),
#  ('here', 34),
#  ('Burn', 32),
#  ('King', 27),
#  ('what', 27),
#  ('Come', 26),
#  ('just', 25),
#  ('tell', 24),
#  ('Look', 24),
#  ('Holy', 24),
#  ('must', 23),
#  ('will', 22),
#  ('That', 22),
#  ('dead', 22),
#  ('from', 20),
#  ('they', 18),
#  ('come', 18),
#  ('very', 17),
#  ('know', 17),
#  ('name', 17),
#  ('were', 16),
#  ('Stop', 16),
#  ('then', 15),
#  ('like', 15),
#  ('into', 15),
#  ('clap', 15),
#  ('ZOOT', 14),
#  ('them', 13),
#  ('CART', 13),
#  ('want', 13),
#  ('more', 13),
#  ('when', 12),
#  ('Shut', 12),
#  ('make', 12),
#  ('sure', 12),
#  ('land', 11),
#  ('mean', 11),
#  ('take', 11),
#  ('much', 11),
#  ('didn', 11),
#  ('find', 11),
#  ('good', 11),
#  ('time', 11),
#  ('room', 11),
#  ('seek', 10),
#  ('back', 10),
#  ('rewr', 10),
#  ('king', 10),
# ...

# %% [markdown]
# ### Exercise 8
#
# Create a set for the words in `text6`. Use a `for` and an `if` statement to loop over the words in the set and print all titlecased words with more than one character, one per line.

# %%
text6_set = set(text6)

for w in text6_set:
    if w.istitle() and len(w)>1:
        print(w)
# Out:
# It
# Zoot
# Between
# Hya
# Galahad
# Anarcho
# Aauuuves
# Therefore
# Dennis
# More
# Which
# Shrubber
# Aaaugh
# Build
# Shut
# Thppt
# Could
# Here
# Explain
# Message
# Divine
# Off
# Thursday
# Wayy
# Aauuugh
# Get
# Loimbard
# Old
# Tale
# Bones
# Ulk
# Clark
# Nador
# Book
# Stop
# Welcome
# Let
# Sir
# Hah
# Together
# Forgive
# Whoa
# Not
# Peril
# Didn
# Unfortunately
# Oooohoohohooo
# At
# Does
# Assyria
# Bridge
# Aggh
# Fine
# Brother
# Hiyaah
# Iesu
# Yapping
# Wood
# Concorde
# Practice
# Alright
# Woa
# Eh
# Hand
# Hoo
# King
# Hm
# Patsy
# Saxons
# Aah
# Hyy
# Is
# Um
# Anthrax
# Lucky
# Use
# Ayy
# Must
# Aaauugh
# Tall
# Course
# Waa
# Then
# Yup
# Go
# Til
# Victory
# Thppppt
# Good
# Idiom
# Skip
# Picture
# Throw
# Do
# Holy
# Ere
# Summer
# Frank
# Guards
# Aauuggghhh
# Arthur
# Ooh
# Nu
# Speak
# Gawain
# Stay
# Hiyya
# Isn
# Hmm
# Pie
# Beyond
# Most
# Aauuuuugh
# Enchanter
# Bedevere
# Alice
# Spring
# Chicken
# Autumn
# Dragon
# Tis
# Maynard
# Camelot
# ...

# %% [markdown]
# ### Exercise 9
#
# Write expressions for finding all words in `text6` that meet the conditions listed below:
#
# a) ending in "ing",
#
# b) containing the letter "z",
#
# c) containing the letter sequence "pt".

# %%
ing_words = [w for w in text6 if w.endswith("ing")]
z_words =[w for w in text6 if "z" in w]
pt_words =[w for w in text6 if "pt" in w]

print("Words ending in 'ing' ")
print(ing_words)

print("Words containing the letter 'z' ")
print(z_words)

print("Words containing the letter sequence 'pt' ")
print(pt_words)
# Out:
# Words ending in 'ing'
# ...

# %% [markdown]
# ### Exercise 10
#
# Define `sent` to be the list of words `['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']`. Now write code to perform the following tasks:
#
# a) print all words beginning with "sh",
#
# b) print all words longer than four characters.

# %%
sent = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']

# %%
for w in sent:
    if w.startswith("sh"):
        print(w)
# Out:
# she
# shells
# shore

# %%
for w in sent:
    if len(w) > 4:
        print(w)
# Out:
# sells
# shells
# shore

# %% [markdown]
# ### Exercise 11
#
# What does the following Python code do?
#
# `sum(len(w) for w in text1)`
#
# Can you use it to work out the average word length of `text1`?

# %% [markdown]
# The code sums up all characters in text1.
#
# We can calculate the average length by deviding by the number of words in text1.

# %%
sum(len(w) for w in text1)/len(text1)
# Out:
# 3.830411128023649

# %% [markdown]
# ### Exercise 12
#
# Define a function `freq(word, text)` that calculates how often a given word occurs in a text, not using `count()` but a `FreqDist`. Use the function to calculate how often "promise" appears in `text4`.

# %%
def freq(word, text):
    fd = FreqDist(text)
    return fd[word]

word_occurance = freq("promise", text4)
print("Number of occurances of the word 'promise' in text 4: ", word_occurance)
# Out:
# Number of occurances of the word 'promise' in text 4:  54
