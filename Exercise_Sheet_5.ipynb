# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 5

# %%
#imports for all exercises
import nltk
from nltk.corpus import brown
from nltk import FreqDist
from collections import defaultdict
from collections import Counter
from nltk.util import ngrams

# %% [markdown]
# ### Exercise 1
#
# Produce a sorted list of tags used in the Brown corpus, removing duplicates. Do the same for the universal part-of-speech tagset.

# %%
# Brown
brown_tagged = nltk.corpus.brown.tagged_words()
brown_no_duplicates = set(tag for w, tag in brown_tagged)
brown_sorted_list = sorted(brown_no_duplicates)
print(brown_sorted_list)
# Out:
# ["'", "''", '(', '(-HL', ')', ')-HL', '*', '*-HL', '*-NC', '*-TL', ',', ',-HL', ',-NC', ',-TL', '--', '---HL', '.', '.-HL', '.-NC', '.-TL', ':', ':-HL', ':-TL', 'ABL', 'ABN', 'ABN-HL', 'ABN-NC', 'ABN-TL', 'ABX', 'AP', 'AP$', 'AP+AP-NC', 'AP-HL', 'AP-NC', 'AP-TL', 'AT', 'AT-HL', 'AT-NC', 'AT-TL', 'AT-TL-HL', 'BE', 'BE-HL', 'BE-TL', 'BED', 'BED*', 'BED-NC', 'BEDZ', 'BEDZ*', 'BEDZ-HL', 'BEDZ-NC', 'BEG', 'BEM', 'BEM*', 'BEM-NC', 'BEN', 'BEN-TL', 'BER', 'BER*', 'BER*-NC', 'BER-HL', 'BER-NC', 'BER-TL', 'BEZ', 'BEZ*', 'BEZ-HL', 'BEZ-NC', 'BEZ-TL', 'CC', 'CC-HL', 'CC-NC', 'CC-TL', 'CC-TL-HL', 'CD', 'CD$', 'CD-HL', 'CD-NC', 'CD-TL', 'CD-TL-HL', 'CS', 'CS-HL', 'CS-NC', 'CS-TL', 'DO', 'DO*', 'DO*-HL', 'DO+PPSS', 'DO-HL', 'DO-NC', 'DO-TL', 'DOD', 'DOD*', 'DOD*-TL', 'DOD-NC', 'DOZ', 'DOZ*', 'DOZ*-TL', 'DOZ-HL', 'DOZ-TL', 'DT', 'DT$', 'DT+BEZ', 'DT+BEZ-NC', 'DT+MD', 'DT-HL', 'DT-NC', 'DT-TL', 'DTI', 'DTI-HL', 'DTI-TL', 'DTS', 'DTS+BEZ', 'DTS-HL', 'DTX', 'EX', 'EX+BEZ', 'EX+HVD', 'EX+HVZ', 'EX+MD', 'EX-HL', 'EX-NC', 'FW-*', 'FW-*-TL', 'FW-AT', 'FW-AT+NN-TL', 'FW-AT+NP-TL', 'FW-AT-HL', 'FW-AT-TL', 'FW-BE', 'FW-BER', 'FW-BEZ', 'FW-CC', 'FW-CC-TL', 'FW-CD', 'FW-CD-TL', 'FW-CS', 'FW-DT', 'FW-DT+BEZ', 'FW-DTS', 'FW-HV', 'FW-IN', 'FW-IN+AT', 'FW-IN+AT-T', 'FW-IN+AT-TL', 'FW-IN+NN', 'FW-IN+NN-TL', 'FW-IN+NP-TL', 'FW-IN-TL', 'FW-JJ', 'FW-JJ-NC', 'FW-JJ-TL', 'FW-JJR', 'FW-JJT', 'FW-NN', 'FW-NN$', 'FW-NN$-TL', 'FW-NN-NC', 'FW-NN-TL', 'FW-NN-TL-NC', 'FW-NNS', '
 'PPO-HL', 'PPO-NC', 'PPO-TL', 'PPS', 'PPS+BEZ', 'PPS+BEZ-HL', 'PPS+BEZ-NC', 'PPS+HVD', 'PPS+HVZ', 'PPS+MD', 'PPS-HL', 'PPS-NC', 'PPS-TL', 'PPSS', 'PPSS+BEM', 'PPSS+BER', 'PPSS+BER-N', 'PPSS+BER-NC', 'PPSS+BER-TL', 'PPSS+BEZ', 'PPSS+BEZ*', 'PPSS+HV', 'PPSS+HV-TL', 'PPSS+HVD', 'PPSS+MD', 'PPSS+MD-NC', 'PPSS+VB', 'PPSS-HL', 'PPSS-NC', 'PPSS-TL', 'QL', 'QL-HL', 'QL-NC', 'QL-TL', 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-NC', 'VBG-TL', 'VBN' ...

# %%
# Universal part-of-speech
universal_tagged = nltk.corpus.brown.tagged_words(tagset='universal')
universal_no_duplicates = set(tag for w, tag in universal_tagged)
universal_sorted_list = sorted(universal_no_duplicates)
print(universal_sorted_list)
# Out:
# ['.', 'ADJ', 'ADP', 'ADV', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PRT', 'VERB', 'X']

# %% [markdown]
# ### Exercise 2
#
# Write a program to process the Brown Corpus using the universal part-of-speech tagset to find out which nouns are more common in their plural form than in their singular form. Only consider regular plurals formed with the "-s" suffix. Print an alphabetically sorted list of the nouns together with the frequencies for the singular and plural forms, one per line.

# %%
# Frequency of all nouns
noun_fd = FreqDist(w.lower() for w, tag in brown.tagged_words(tagset='universal') if tag == 'NOUN')

# Going through all nouns and checking if they have their plural form
# If yes -> comparing the frequecies
# If plural > singular -> add (noun, sing freq, plur freq) to list
# sort and print
more_common_plural = []

for noun in noun_fd:
    plural_noun = noun + "s"
    
    if plural_noun in noun_fd and noun_fd[plural_noun]>noun_fd[noun]:
        more_common_info = (noun, noun_fd[noun], noun_fd[plural_noun])
        more_common_plural.append(more_common_info)
    
    #if plural_noun not in noun_fd:
        #more_common_info = (noun, noun_fd[noun], 0)
        #more_common_plural.append(more_common_info)


sorted_result = sorted(more_common_plural)

for noun, s_freq, p_freq in sorted_result:
    print(f"Noun: {noun}, Singular count: {s_freq}, Plural count: {p_freq}")

# NOTE: Only singular words that HAVE their plural form are considered.
# Out:
# Noun: 2-year-old, Singular count: 2, Plural count: 3
# Noun: aberration, Singular count: 3, Plural count: 5
# Noun: abolitionist, Singular count: 1, Plural count: 4
# Noun: aborigine, Singular count: 7, Plural count: 8
# Noun: absolute, Singular count: 1, Plural count: 3
# Noun: vegetable, Singular count: 10, Plural count: 16
# Noun: vehicle, Singular count: 35, Plural count: 53
# Noun: vendor, Singular count: 1, Plural count: 2
# Noun: verb, Singular count: 4, Plural count: 7
# Noun: villain, Singular count: 3, Plural count: 4
# Noun: vine, Singular count: 4, Plural count: 8
# Noun: vineyard, Singular count: 2, Plural count: 5
# Noun: visitor, Singular count: 13, Plural count: 36
# Noun: vitamin, Singular count: 5, Plural count: 10
# Noun: volunteer, Singular count: 5, Plural count: 29
# Noun: voter, Singular count: 4, Plural count: 20
# Noun: vow, Singular count: 2, Plural count: 4
# Noun: wandering, Singular count: 1, Plural count: 3
# Noun: warrior, Singular count: 5, Plural count: 7
# Noun: watershed, Singular count: 3, Plural count: 4
# Noun: waterway, Singular count: 2, Plural count: 3
# Noun: wave, Singular count: 44, Plural count: 51
# Noun: wavelength, Singular count: 4, Plural count: 6
# Noun: weapon, Singular count: 42, Plural count: 61
# Noun: weave, Singular count: 1, Plural count: 2
# Noun: williams', Singular count: 1, Plural count: 2
# Noun: win, Singular count: 1, Plural count: 3
# Noun: wing, Singular count: 17, Plural count: 27
# Noun: worker, Singular count: 30, Plural count: 86
# Noun: worm, Singular count: 4, Plural count: 5
# Noun: wrinkle, Singular count: 2, Plural count: 7
# Noun: yankee, Singular count: 10, Plural count: 28
# Noun: yard, Singular count: 35, Plural count: 64
# Noun: year, Singular count: 656, Plural count: 949
# Noun: youngster, Singular count: 8, Plural count: 18

# %% [markdown]
# ### Exercise 3
#
# Find out which word has the greatest number of distinct tags in the Brown corpus using the original tagset. Without using the `most_common` function, print a list of the tags together with the frequencies for the word, sorted by frequency from highest to lowest, one per line.

# %%
tagged = brown.tagged_words()
tagged_dict = defaultdict(set)

for word, tag in tagged:
    tagged_dict[word.lower()].add(tag)

# Word with greatest number of distinct tags:

max_tags = 0
most_tagged = None
for word, tags in tagged_dict.items():
    tags_count = len(tags)
    if tags_count > max_tags:
        max_tags = tags_count
        most_tagged = word

#print (most_tagged, max_tags)

# Going through corpus to now count the tag frequencies
tag_freqs = Counter()

for word, tag in tagged:
    if word.lower() == most_tagged:
        tag_freqs[tag] +=1

# Sort by frequency (reverse)
sorted_result = sorted(tag_freqs.items(), key = lambda x: x[1], reverse = True)

print(f"Word with greatest # of distinct tags: {most_tagged}, Number of tags: {max_tags}")
    
for tag, freq in sorted_result:
    print(f"Tag: {tag}, Frequency: {freq}")
# Out:
# Word with greatest # of distinct tags: that, Number of tags: 15
# Tag: CS, Frequency: 6464
# Tag: DT, Frequency: 2260
# Tag: WPS, Frequency: 1654
# Tag: WPO, Frequency: 135
# Tag: QL, Frequency: 56
# Tag: DT-NC, Frequency: 6
# Tag: DT-TL, Frequency: 5
# Tag: WPS-TL, Frequency: 3
# Tag: WPS-NC, Frequency: 3
# Tag: CS-NC, Frequency: 2
# Tag: WPS-HL, Frequency: 2
# Tag: CS-HL, Frequency: 1
# Tag: DT-HL, Frequency: 1
# Tag: NIL, Frequency: 1
# Tag: WPO-NC, Frequency: 1

# %% [markdown]
# ### Exercise 4
#
# Tabulate the frequencies of the universal tags that precede nouns in the Brown Corpus.

# %%
tagged = brown.tagged_words(tagset='universal')

tags_preceding_nouns = []

for i in range (1, len(tagged)): # starting from 2nd word (1st has no preceding tags)
    curr_word, curr_tag = tagged[i] 
    if curr_tag == "NOUN": # if noun then
        prev_word, prev_tag = tagged[i-1] # get the preceding
        tags_preceding_nouns.append(prev_tag) # add to the list
        
fd = FreqDist(tags_preceding_nouns)
fd.tabulate()
# Out:
#   DET   ADJ  NOUN   ADP     .  VERB  CONJ   NUM   ADV   PRT  PRON     X
# 85845 54653 41309 37418 20084 17851  9294  5668  1851  1068   440    77

# %% [markdown]
# ### Exercise 5
#
# Write a function `ambiguous(tagged_text)` that returns the number of ambiguous word types as well as the number of all word types in a tagged text. A word type is ambiguous if it is tagged with at least two different tags. Use the function to print both values as well as the percentage of ambiguous word types for the Brown Corpus both for the original and the universal tagset.

# %%
def ambiguous(tagged_text):
    
    tagged_dict = defaultdict(set)

    for word, tag in tagged_text:
        tagged_dict[word.lower()].add(tag)
        
    total_n_word_types = len(tagged_dict)
    ambiguous_n_word_types = 0
        
    for word, tags in tagged_dict.items():
        if len(tags) > 1: # at least two different tags
            ambiguous_n_word_types +=1
    
    percentage_ambiguous = (ambiguous_n_word_types/total_n_word_types)*100 # calculate percentage
    
    print(f"Total # of word types: {total_n_word_types}")
    print(f"# of ambiguous word types: {ambiguous_n_word_types}")
    print(f"Percentage of ambiguous word types: {percentage_ambiguous:.2f}%")
    
    return total_n_word_types, ambiguous_n_word_types, percentage_ambiguous

print("Original:")
ambiguous(brown.tagged_words())
print("\n")
print("Universal:")
ambiguous(brown.tagged_words(tagset='universal'))
# Out:
# Original:
# Total # of word types: 49815
# # of ambiguous word types: 9580
# Percentage of ambiguous word types: 19.23%
#
#
# Universal:
# Total # of word types: 49815
# # of ambiguous word types: 3408
# Percentage of ambiguous word types: 6.84%
# (49815, 3408, 6.84131285757302)

# %% [markdown]
# ### Exercise 6
#
# Write code to search the Brown Corpus to answer the following questions:
#
# a) produce an alphabetically sorted list of the distinct words tagged as `MD`
# b) identify words that can be plural nouns or third person singular verbs
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form `IN+AT+NN`, separated by semicolons

# %%
# a). produce an alphabetically sorted list of the distinct words tagged as MD

distinct_md = sorted(set(word.lower() for word, tag in brown.tagged_words() if tag == 'MD'))
print(distinct_md)
# Out:
# ["c'n", 'can', 'colde', 'could', 'dare', 'kin', 'maht', 'mai', 'may', 'maye', 'mayst', 'might', 'must', 'need', 'ought', 'shall', 'should', 'shuld', 'shulde', 'wil', 'will', 'wilt', 'wod', 'wold', 'wolde', 'would']

# %%
# b). identify words that can be plural nouns or third person singular verbs

result_words = set()

for word,tag in brown.tagged_words():
    if tag in ['NNS', 'VBZ'] and word.isalpha(): # additionally only consists of valid letters
        result_words.add((word.lower(), tag))

sorted_result = sorted(result_words) #sorting the result
print(sorted_result)
# Out:
# [('abberations', 'NNS'), ('abbreviations', 'NNS'), ('aberrations', 'NNS'), ('abides', 'VBZ'), ('abilities', 'NNS'), ('abnormalities', 'NNS'), ('abolitionists', 'NNS'), ('aborigines', 'NNS'), ('abortions', 'NNS'), ('abounds', 'VBZ'), ('abscesses', 'NNS'), ('absences', 'NNS'), ('absolutes', 'NNS'), ('absorbs', 'VBZ'), ('absorptions', 'NNS'), ('abstractionists', 'NNS'), ('abstractions', 'NNS'), ('abstractors', 'NNS'), ('abstracts', 'NNS'), ('abstrusenesses', 'NNS'), ('absurdities', 'NNS'), ('abuses', 'NNS'), ('abutments', 'NNS'), ('academics', 'NNS'), ('academies', 'NNS'), ('accelerations', 'NNS'), ('accelerators', 'NNS'), ('accelerometers', 'NNS'), ('accents', 'NNS'), ('accentuates', 'VBZ'), ('accepts', 'VBZ'), ('accesses', 'NNS'), ('accessions', 'NNS'), ('accessories', 'NNS'), ('accidents', 'NNS'), ('acclaims', 'VBZ'), ('accolades', 'NNS'), ('accommodates', 'VBZ'), ('accommodations', 'NNS'), ('accomodations', 'NNS'), ('accompanies', 'VBZ'), ('accompaniments', 'NNS'), ('accompanists', 'NNS'), ('accomplices', 'NNS'), ('accomplishes', 'VBZ'), ('accomplishments', 'NNS'), ('accords', 'VBZ'), ('accountants', 'NNS'), ('accounts', 'NNS'), ('accounts', 'VBZ'), ('accouterments', 'NNS'), ('accretions', 'NNS'), ('accrues', 'VBZ'), ('accumulates', 'VBZ'), ('accusations', 'NNS'), ('accuses', 'VBZ'), ('aces', 'NNS'), ('aches', 'VBZ'), ('achievements', 'NNS'), ('achieves', 'VBZ'), ('acids', 'NNS'), ('acknowledges', 'VBZ'), ('acknowledgments', 'NNS'), ('acorns', 'NNS'), ('acoustics', 'NNS'), ('acquires', 'VBZ'), ('acquisitions', 'NNS'), ('acres', 'NNS'), ('acrobats', 'NNS'), ('actions', 'NNS'), ('actives', 'NNS'), ('activities', 'NNS'), ('actors', 'NNS'), ('actresses', 'NNS'), ('acts', 'NNS'), ('acts', 'VBZ'), ('actualities', 'NNS'), ('adagios', 'NNS'), ('adaptations', 'NNS'), ('adapters', 'NNS'), ('addicts', 'NNS'), ('additions', 'NNS'), ('additives', 'NNS'), ('addressees', 'NNS'), ('addresses', 'NNS'), ('addresses', 'VBZ'), ('adds', 'VBZ'), ('adenomas', 'NNS'), ('adherents', 'NNS'), ('adheres', 'VBZ'), ('adhesives', 'NNS'), ('adjectives', 'NNS'), ('adjoins', 'VBZ'), ('adjourns', 'VBZ'), ('adjuncts', 'NNS'), ('adjustments', 'NNS'), ('adjusts', 'VBZ'), ('administers', 'VBZ'), ('administrators', 'NNS'), ('admirals', 'NNS'), ('admirers', 'NNS'), ('admires', 'VBZ'), ('admissions', 'NNS'), ('admits', 'VBZ'), ('admonishments', 'NNS'), ('admonitions', 'NNS'), ('adolescents', 'NNS'), ('adopts', 'VBZ'), ('adores', 'VBZ'), ('adorns', 'VBZ'), ('ads', 'NNS'), ('adsorbs', 'VBZ'), ('adulterers', 'NNS'), ('adults', 'NNS'), ('advancements', 'NNS'), ('advances', 'NNS'), ('advances', 'VBZ'), ('advantages', 'NNS'), ('adventurers', 'NNS'), ('adventures', 'NNS'), ('adverbs', 'NNS'), ('adversaries', 'NNS'), ('advertisements', 'NNS'), ('advertisers', 'NNS'), ('advertises', 'VBZ'), ('advisers', 'NNS'), ('advises', 'VBZ'), ('advisors', 'NNS'), ('advocates', 'NNS'), ('aerates', 'VBZ'), ('aerials', 'NNS'), ('aerosols', 'NNS'), ('aesthetes', 'NNS'), ('affairs', 'NNS'), ('affections', 'NNS'), ('affects', 'NNS'), ('affects', 'VBZ'), ('affidavits', 'NNS'), ('affiliates', 'NNS'), ('affiliations', 'NNS'), ('affinities', 'NNS'), ('affirmations', 'NNS'), ('affirms', 'VBZ'), ('afflictions', 'NNS'), ('affords', 'VBZ'), ('afternoons', 'NNS'), ('agates', 'NNS'), ('agencies', 'NNS'), ('agenda', 'NNS'), ('agents', 'NNS'), ('ages', 'NNS'), ('agglutinins', 'NNS'), ('aggravates', 'VBZ'), ('aggregations', 'NNS'), ('aggressions', 'NNS'), ('agitators', 'NNS'), ('agnostics', 'NNS'), ('agonies', 'NNS'), ('agonizes', 'VBZ'), ('agreements', 'NNS'), ('agrees', 'VBZ'), ('aides', 'NNS'), ('aids', 'NNS'), ('aids', 'VBZ'), ('ailerons', 'NNS'), ('ailments', 'NNS'), ('aims', 'NNS'), ('aims', 'VBZ'), ('aircraft', 'NNS'), ('airdrops', 'NNS'), ('airfields', 'NNS'), ('airlines', 'NNS'), ('airmen', 'NNS'), ('airplanes', 'NNS'), ('airports', 'NNS'), ('airs', 'NNS'), ('airstrips', 'NNS'), ('airways', 'NNS'), ('alarms', 'NNS'), ('albums', 'NNS'), ('alcoholics', 'NNS'), ('alcohols', 'NNS'), ('alcoves', 'NNS') ...

# %%
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form IN+AT+NN,
# separated by semicolons

result_phrases = set()

for sentence in brown.tagged_sents():
    for w1,w2,w3 in ngrams(sentence,3): # generating trigrams and going through them directly
        if(w1[1] == 'IN' and w2[1] == 'AT' and w3[1] == 'NN'):
            result_phrases.add(f"{w1[0]} {w2[0]} {w3[0]}")

print(';'.join(sorted(result_phrases)))
# Out:
# 'bout the saddle;'ceptin' the light;About the murder;Above the tongue;Across the bay;Across the bridge;Across the front;Across the road;Across the street;Across the table;Across the way;After a conversation;After a day;After a dinner;After a flood;After a minute;After a moment;After a pause;After a reception;After a roundup;After a sort;After a supper;After a time;After a while;After a year;After an earthquake;After every money;After every session;After the collapse;After the demise;After the diagnosing;After the game;After the meal;After the meeting;After the pegboard;After the soil;After the spate;After the storm;After the war;Against the ruin;Along the way;Amid a shortage;Amid the crackle;Among the policy;Around the billiard;Around the table;As a result;At a ceremony;At a minimum;At a nod;At a party;At a rate;At a reception;At a siding;At no time;At the Seashore;At the adoption;At the age;At the base;At the beginning;At the bottom;At the close;At the conclusion;At the door;At the doorway;At the edge;At the end;At the entrance;At the gate;At the head;At the heart;At the height;At the inn;At the inquest;At the insistence;At the landing;At the meeting;At the moment;At the nadir;At the opening;At the order;At the outset;At the peak;At the point;At the rate;At the rear;At the risk;At the scene;At the sight;At the start;At the time;At the top;At the trial;At the workshop;Below the fort;Beneath the dome;Besides the bundle;Besides the lack;Besides the presence;Between the telephone;Beyond the forest;Beyond the stockade;By a combination;By an effort;By the age;By the death;By the end;By the look;By the middle;By the time;By the use;By the way;Concerning the sentence;Considering the nature;Considering the state;Despite an ambiguity;Despite the clarity;Despite the excitement;Despite the fact;Despite the hopelessness;Despite the lip;Despite the opposition;Despite the recession;Despite the rejection;Down the boulevard;Down the tree;During a round;During a sojourn;During the assignment;During the biennium;During the course;During the decade;During the discharge;During the election;During the excitement;During the making;During the month;During the morning;During the night;During the pension;During the period;During the quarrel;During the rest;During the return;During the summer;During the trial;During the trip;During the war;During the year;Following the term;For a chemical;For a man;For a minute;For a moment;For a number;For a resort;For a steak;For a time;For a while;For a year;For an anthropologist;For an antique;For an engine;For an example;For an experiment;For an instant;For every person;For the albumin;For the army;For the boy;For the case;For the convenience;For the dignity;For the figure;For the future;For the government;For the industry;For the interpretation;For the low-temperature;For the maintenance;For the marksman;For the moment;For the occasion;For the present;For the president;For the prevention;For the purpose;For the reason;For the remainder;For the school;For the treatment;For the use;For the vertex;For the year;From a man;From a pen;From an exercise;From the back;From the beginning;From the brightness;From the coil;From the collection;From the crowd;From the curio;From the equilibrium;From the evidence;From the luggage;From the man;From the moment;From the night;From the outset;From the outside;From the point;From the standpoint;From the time;From the town;From the volume;From the way;From the wealth;In a B;In a book;In a camp;In a climate;In a controversy;In a course;In a flash;In a fraction;In a frenzy;In a kind;In a letter;In a matter;In a minute;In a neighborhood;In a sample;In a saucepan;In a sense;In a series;In a set;In a society;In a story;In a stream;In a succession;In a symposium;In a time;In a total;In a tour;In a voice;In a waterfall;In a way;In a week;In a word;In a year;In an FELA;In an age;In an attempt;In an effort;In an emergency;In an hour;In an instant;In every aspect;In every war;In no way;In the  ...

# %% [markdown]
# ### Exercise 7
#
# Write a function `prec_adv(word, text)` that returns an alphabetically sorted list of distinct adverbs that precede `word` in `text`. Use this function to find out which adverbs precede the words "love", "like", and "prefer" in the Brown corpus.

# %%
def prec_adv(word, text):
    
    adverbs=set()
    
    for i in range (1, len(text)): # starting from 2nd word (1st has no preceding tags)
        curr_word, curr_tag = text[i] 
        
        if curr_word == word: 
            prev_word, prev_tag = text[i-1] # get the preceding
            
            if prev_tag in ['RB']:
                adverbs.add(prev_word) # add to the set

    return sorted(list(adverbs))


# TESTING:

# love
print("Adverbs preceding 'love':")
love_result = prec_adv("love", brown.tagged_words())
print(love_result)

# like
print("Adverbs preceding 'like':")
like_result = prec_adv("like", brown.tagged_words())
print(like_result)

# prefer
print("Adverbs preceding 'prefer':")
prefer_result = prec_adv("prefer", brown.tagged_words())
print(prefer_result)
# Out:
# Adverbs preceding 'love':
# ['always', 'dearly', 'just']
# Adverbs preceding 'like':
# ['Jist', 'Just', 'Kinda', 'abreast', 'almost', 'alone', 'always', 'around', 'by', 'close', 'deceptively', 'even', 'exactly', 'gloriously', 'here', 'increasingly', 'jist', 'just', 'much', 'often', 'particularly', 'quick', 'rather', 'remarkably', 'roughly', 'simply', 'so', 'somewhat', 'sure', 'there', 'together', 'wildly', 'yet']
# Adverbs preceding 'prefer':
# ['generally', 'much', 'spontaneously']
